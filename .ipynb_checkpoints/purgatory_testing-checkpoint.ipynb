# %% [markdown]
# ## Testing for unusable pictures
#
# This file takes images from my "pugatory" folder to test if they will be able to flow through my model or not.

# %%
# !pip install filetype
# Out:
# Collecting filetype
#   Downloading https://files.pythonhosted.org/packages/b4/6b/7bc015da1a576ac037582ae0c5acb675371de9e017e860931e97a428ee31/filetype-1.0.7-py2.py3-none-any.whl
# Installing collected packages: filetype
# Successfully installed filetype-1.0.7

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, MaxPool2D, Dropout, Flatten, GlobalAveragePooling2D

import os
import concurrent.futures
import cv2
import filetype

# %%
# mount to Google Drive
# data is saved in the test_data folder of my Drive, link is in README for anyone to access.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def worker(filepath, filename):

  """
  This function is used to submit work to the image_checker function
  this worker detects if a file is an image, then deletes if its not
  filepath: full path to the file being treated
  filename: name of the file being treated  
  """

  kind = filetype.guess(filepath)  # tries to guess file type based on header
  if kind is None:
      print('Cannot guess file type for file', filename, 'Deleting it!')
      os.remove(filepath)  # deletes file
  elif 'image' not in kind.mime:
      print(f"File {filepath} is not an image. File type: {kind.extension}")
  else:
      try:  # if file is detected as an image from the header then try to open it
          img = cv2.imread(filepath)  # if successful then file is indeed an image.
          size = img.shape
          print(f'{filepath} is an image. File type:{kind.extension}')
      except:
          print(f'file {filepath} is not a valid image file ')
          os.remove(filepath)  # deletes file


def image_checker(folder_path):

  """
  This function will iterate over all files in a folder and runs the image checker worker on them
  It takes advantage of multi threading, which allows it to run loop iterations in separate threads(max=10). 
  The benefits of it being that the code doesnt need to wait for the end of the execution of one iteration in order to start working on the next file
  It will keep assigning files to check to threads as long as there are threads idle.
  This speeds us the process of running the code. 
  """

  for subdir, dirs, files in os.walk(folder_path):  # this will loop over every file in every sub directory in data/
       with concurrent.futures.ThreadPoolExecutor() as e:
          for filename in files:
              filepath = f'{subdir}/{filename}'
              e.submit(worker, filepath, filename)

# %%
image_checker('drive/MyDrive/capstone_translator/purgatory')
# Out:
# Streaming output truncated to the last 5000 lines.
# drive/MyDrive/capstone_translator/purgatory/fork/Image_44.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_35.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_37.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_48.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_42.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_43.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_40.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_46.jpg is an image. File type:webp
# drive/MyDrive/capstone_translator/purgatory/fork/Image_50.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_53.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_55.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_51.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_47.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_62.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_56.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_58.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_49.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_54.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_63.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_52.jpg is an image. File type:webp
# drive/MyDrive/capstone_translator/purgatory/fork/Image_64.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_34.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_60.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_45.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_67.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_68.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_65.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_66.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_61.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_59.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_57.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_74.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_69.jpg is an image. File type:jpgdrive/MyDrive/capstone_translator/purgatory/fork/Image_78.jpg is an image. File type:jpg
#
# drive/MyDrive/capstone_translator/purgatory/fork/image(239).jpg is an image. File type:jpgdrive/MyDrive/capstone_translator/purgatory/fork/Image_72.jpg is an image. File type:jpg
#
# drive/MyDrive/capstone_translator/purgatory/fork/Image_33.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_77.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_82.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_70.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_83.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_80.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_79.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_75.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_76.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_84.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_73.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_85.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_86.JPG is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_87.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_88.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_90.jpeg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_91.jpg is an image. File type:jpgdrive/MyDrive/capstone_translator/purgatory/fork/Image_92.jpg is an image. File type:jpg
#
# drive/MyDrive/capstone_translator/purgatory/fork/Image_81.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_94.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_95.jpg is an image. File type:webpdrive/MyDrive/capstone_translator/purgatory/fork/Image_96.jpg is an image. File type:jpg
#
# drive/MyDrive/capstone_translator/purgatory/fork/Image_99.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_71.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_89.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_93.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_98.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_97.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_103.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_107.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_102.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_100.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_101.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_110.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_104.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_111.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_108.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_113.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_106.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_114.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_115.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_112.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_105.jpg is an image. File type:jpgdrive/MyDrive/capstone_translator/purgatory/fork/Image_116.jpg is an image. File type:jpg
#
# drive/MyDrive/capstone_translator/purgatory/fork/Image_109.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_121.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_120.JPG is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_126.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_127.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_125.jpg is an image. File type:webp
# drive/MyDrive/capstone_translator/purgatory/fork/Image_119.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_124.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_123.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_122.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_128.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_118.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_133.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_117.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_132.png is an image. File type:png
# drive/MyDrive/capstone_translator/purgatory/fork/Image_136.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_129.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_135.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_137.JPG is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_131.jpg is an image. File type:jpgdrive/MyDrive/capstone_translator/purgatory/fork/Image_140.jpg is an image. File type:jpg
#
# drive/MyDrive/capstone_translator/purgatory/fork/Image_138.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_130.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_141.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_134.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_139.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_148.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_146.jpg is an image. File type:webp
# drive/MyDrive/capstone_translator/purgatory/fork/Image_155.jpg is an image. File type:webp
# drive/MyDrive/capstone_translator/purgatory/fork/Image_158.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_147.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_152.jpg is an image. File type:webp
# drive/MyDrive/capstone_translator/purgatory/fork/Image_144.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_149.jpeg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_145.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image_159.jpg is an image. File type:jpg
# drive/MyDrive/capstone_translator/purgatory/fork/Image