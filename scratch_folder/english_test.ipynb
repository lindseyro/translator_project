# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
pd.read_csv('./english-2/index-english-02-package.tsv', sep='\t')
# Out:
#            was ruled     0
# 0       the security     1
# 1       next morning    10
# 2        be realized   100
# 3     yonemura shoji  1000
# 4      compact discs  1001
# ...              ...   ...
# 9994         wilhelm  9995
# 9995   lunar mission  9996
# 9996    they will be  9997
# 9997         odawara  9998
# 9998          borbon  9999
#
# [9999 rows x 2 columns]

# %%
plt.imshow(plt.imread('/Users/Lindsey/Documents/dsir-322/capstone/english-2/mini-english-02-package/9995/01.jpg'))

# %%
english_1 = pd.read_csv('./english-1/index-english-01-package.tsv', sep='\t')
english_1.head(25)
# Out:
#                          all his life     0
# 0                             mango's     1
# 1                              10 tam    10
# 2                            put down   100
# 3                              gabble  1000
# 4                                phot  1001
# 5                             sansaru  1002
# 6                       the operative  1003
# 7                         for seconds  1004
# 8                              a time  1005
# 9                       the full-back  1006
# 10                       jacob (name)  1007
# 11                              gugga  1008
# 12                  community-spanish  1009
# 13                              302nd   101
# 14                          morabitin  1010
# 15                       ice crystals  1011
# 16  pashupatinath (a temple in nepal)  1012
# 17                                pun  1013
# 18                             muukku  1014
# 19                          korupsyon  1015
# ...

# %%
plt.imshow(plt.imread('/Users/Lindsey/Documents/dsir-322/capstone/english-1/mini-english-01-package/1011/01.jpg'))

# %%
pd.read_csv('./french/index-french-package.tsv', sep='\t')
# Out:
#                 $     0
# 0               =     1
# 1             abc    10
# 2        actrices   100
# 3           béton  1000
# 4            bœuf  1001
# ...           ...   ...
# 9881    bénéficie   995
# 9882  bénéficient   996
# 9883   bénéficier   997
# 9884    bénéficié   998
# 9885       bétail   999
#
# [9886 rows x 2 columns]

# %%
plt.imshow(plt.imread('/Users/Lindsey/Documents/dsir-322/capstone/french/mini-french-package/1001/01.jpg'))

# %%
pd.read_csv('./english-2/index-english-02-package.tsv', sep='\t')
# Out:
#            was ruled     0
# 0       the security     1
# 1       next morning    10
# 2        be realized   100
# 3     yonemura shoji  1000
# 4      compact discs  1001
# ...              ...   ...
# 9994         wilhelm  9995
# 9995   lunar mission  9996
# 9996    they will be  9997
# 9997         odawara  9998
# 9998          borbon  9999
#
# [9999 rows x 2 columns]
